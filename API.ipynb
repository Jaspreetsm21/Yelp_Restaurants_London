# %%
import pandas as pd
import json
import requests

# %%
API_KEY = 'your_api_key'
CLIENT_ID = 'your_client_id'

URL = "https://api.yelp.com/v3/businesses/search"

headers = {'Authorization': 'bearer %s' % API_KEY}

params = {'term': 'restaurants',
              'offset': 0,
              'limit': 50,
              'radius': 40000,
              'location': 'london, UK'}

response = requests.get(url=URL, params=params, headers=headers)

# %%
py_data = response.json()

# %%
yelp_data = open("categories.json",'w')  
    
json.dump(py_data, yelp_data, indent = 6)  
    
yelp_data.close()

# %%
# yelp has category of restaurants and they provide json file for that 
# I used a json file from the github post - https://gist.github.com/cristinecula/c7b1c6aa5ddb74789db9
with open('yelp_categories.json') as f:
    data = json.load(f)

restaurants = dict((k, v) for (k, v) in data.items() if v == 'restaurants')
restaurants
# Out:
# {'restaurants': 'restaurants',
#  'afghani': 'restaurants',
#  'african': 'restaurants',
#  'senegalese': 'restaurants',
#  'southafrican': 'restaurants',
#  'newamerican': 'restaurants',
#  'tradamerican': 'restaurants',
#  'arabian': 'restaurants',
#  'argentine': 'restaurants',
#  'armenian': 'restaurants',
#  'asianfusion': 'restaurants',
#  'australian': 'restaurants',
#  'austrian': 'restaurants',
#  'bangladeshi': 'restaurants',
#  'bbq': 'restaurants',
#  'basque': 'restaurants',
#  'belgian': 'restaurants',
#  'brasseries': 'restaurants',
#  'brazilian': 'restaurants',
#  'breakfast_brunch': 'restaurants',
#  'british': 'restaurants',
#  'buffets': 'restaurants',
#  'burgers': 'restaurants',
#  'burmese': 'restaurants',
#  'cafeteria': 'restaurants',
#  'cajun': 'restaurants',
#  'cambodian': 'restaurants',
#  'caribbean': 'restaurants',
#  'dominican': 'restaurants',
#  'haitian': 'restaurants',
#  'puertorican': 'restaurants',
#  'trinidadian': 'restaurants',
#  'catalan': 'restaurants',
#  'cheesesteaks': 'restaurants',
#  'chicken_wings': 'restaurants',
#  'chinese': 'restaurants',
#  'cantonese': 'restaurants',
#  'dimsum': 'restaurants',
#  'shanghainese': 'restaurants',
#  'szechuan': 'restaurants',
#  'comfortfood': 'restaurants',
#  'creperies': 'restaurants',
#  'cuban': 'restaurants',
#  'czech': 'restaurants',
#  'delis': 'restaurants',
#  'diners': 'restaurants',
#  'ethiopian': 'restaurants',
#  'hotdogs': 'restaurants',
#  'filipino': 'restaurants',
#  'fishnchips': 'restaurants',
#  'fondue': 'restaurants',
#  'food_court': 'restaurants',
#  'foodstands': 'restaurants',
#  'french': 'restaurants',
#  'gastropubs': 'restaurants',
#  'german': 'restaurants',
#  'gluten_free': 'restaurants',
#  'greek': 'restaurants',
#  'halal': 'restaurants',
#  'hawaiian': 'restaurants',
#  'himalayan': 'restaurants',
#  'hotdog': 'restaurants',
#  'hotpot': 'restaurants',
#  'hungarian': 'restaurants',
#  'iberian': 'restaurants',
#  'indpak': 'restaurants',
#  'indonesian': 'restaurants',
#  'irish': 'restaurants',
#  'italian': 'restaurants',
#  'japanese': 'restaurants',
#  'ramen': 'restaurants',
#  'korean': 'restaurants',
#  'kosher': 'restaurants',
#  'laotian': 'restaurants',
#  'latin': 'restaurants',
#  'colombian': 'restaurants',
#  'salvadoran': 'restaurants',
#  'venezuelan': 'restaurants',
#  'raw_food': 'restaurants',
#  'malaysian': 'restaurants',
#  'mediterranean': 'restaurants',
#  'falafel': 'restaurants',
#  'mexican': 'restaurants',
#  'mideastern': 'restaurants',
#  'egyptian': 'restaurants',
#  'lebanese': 'restaurants',
#  'modern_european': 'restaurants',
#  'mongolian': 'restaurants',
#  'moroccan': 'restaurants',
#  'pakistani': 'restaurants',
#  'persian': 'restaurants',
#  'peruvian': 'restaurants',
#  'pizza': 'restaurants',
#  'polish': 'restaurants',
#  'portuguese': 'restaurants',
#  'russian': 'restaurants',
#  'salad': 'restaurants',
#  'sandwiches': 'restaurants',
#  'scandinavian': 'restaurants',
#  'scottish': 'restaurants',
#  'seafood': 'restaurants',
#  'singaporean': 'restaurants',
#  'slovakian': 'restaurants',
#  'soulfood': 'restaurants',
#  'soup': 'restaurants',
#  'southern': 'restaurants',
#  'spanish': 'restaurants',
#  'steak': 'restaurants',
#  'sushi': 'restaurants',
#  'taiwanese': 'restaurants',
#  'tapas': 'restaurants',
#  'tapasmallplates': 'restaurants',
#  'mex': 'restaurants',
#  'thai': 'restaurants',
#  'turkish': 'restaurants',
#  'ukrainian': 'restaurants',
#  'uzbek': 'restaurants',
#  'vegan': 'restaurants',
#  'vegetarian': 'restaurants',
#  'vietnamese': 'restaurants'}

# %%
# for key in restaurants.keys():
#     print(key)

# %%
import time
yelp_restaurants = []
# Cycle through categories
for category in restaurants.keys():
    params['categories'] = category
    # Cycle through restaurants
    for offset_number in range(0,1000,50):
        params['offset'] = offset_number

        response = requests.get(url=URL, params=params, headers=headers)

        if not response.json().get('businesses', False):
            break

        yelp_restaurants.extend(response.json()['businesses'])

        print("{}: {}-{}".format(category, offset_number, offset_number+50))
        
        time.sleep(0.5)
# Out:
# restaurants: 0-50
# restaurants: 50-100
# restaurants: 100-150
# restaurants: 150-200
# restaurants: 200-250
# restaurants: 250-300
# restaurants: 300-350
# restaurants: 350-400
# restaurants: 400-450
# restaurants: 450-500
# restaurants: 500-550
# restaurants: 550-600
# restaurants: 600-650
# restaurants: 650-700
# restaurants: 700-750
# restaurants: 750-800
# restaurants: 800-850
# restaurants: 850-900
# restaurants: 900-950
# restaurants: 950-1000
# afghani: 0-50
# african: 0-50
# african: 50-100
# newamerican: 0-50
# newamerican: 50-100
# tradamerican: 0-50
# tradamerican: 50-100
# tradamerican: 100-150
# tradamerican: 150-200
# arabian: 0-50
# argentine: 0-50
# asianfusion: 0-50
# asianfusion: 50-100
# asianfusion: 100-150
# asianfusion: 150-200
# australian: 0-50
# austrian: 0-50
# bangladeshi: 0-50
# bbq: 0-50
# bbq: 50-100
# basque: 0-50
# belgian: 0-50
# brasseries: 0-50
# brasseries: 50-100
# brazilian: 0-50
# breakfast_brunch: 0-50
# breakfast_brunch: 50-100
# breakfast_brunch: 100-150
# breakfast_brunch: 150-200
# breakfast_brunch: 200-250
# breakfast_brunch: 250-300
# breakfast_brunch: 300-350
# breakfast_brunch: 350-400
# breakfast_brunch: 400-450
# breakfast_brunch: 450-500
# breakfast_brunch: 500-550
# breakfast_brunch: 550-600
# breakfast_brunch: 600-650
# breakfast_brunch: 650-700
# breakfast_brunch: 700-750
# british: 0-50
# british: 50-100
# british: 100-150
# british: 150-200
# british: 200-250
# british: 250-300
# british: 300-350
# british: 350-400
# british: 400-450
# british: 450-500
# british: 500-550
# british: 550-600
# british: 600-650
# british: 650-700
# british: 700-750
# british: 750-800
# british: 800-850
# british: 850-900
# british: 900-950
# british: 950-1000
# buffets: 0-50
# burgers: 0-50
# burgers: 50-100
# burgers: 100-150
# burgers: 150-200
# burgers: 200-250
# burgers: 250-300
# burgers: 300-350
# burgers: 350-400
# burgers: 400-450
# burmese: 0-50
# cafeteria: 0-50
# cambodian: 0-50
# caribbean: 0-50
# caribbean: 50-100
# caribbean: 100-150
# cheesesteaks: 0-50
# chicken_wings: 0-50
# chicken_wings: 50-100
# chinese: 0-50
# chinese: 50-100
# chinese: 100-150
# chinese: 150-200
# chinese: 200-250
# chinese: 250-300
# chinese: 300-350
# chinese: 350-400
# chinese: 400-450
# chinese: 450-500
# chinese: 500-550
# chinese: 550-600
# chinese: 600-650
# cantonese: 0-50
# dimsum: 0-50
# dimsum: 50-100
# szechuan: 0-50
# creperies: 0-50
# cuban: 0-50
# czech: 0-50
# delis: 0-50
# delis: 50-100
# delis: 100-150
# delis: 150-200
# delis: 200-250
# diners: 0-50
# diners: 50-100
# ethiopian: 0-50
# hotdogs: 0-50
# hotdogs: 50-100
# hotdogs: 100-150
# hotdogs: 150-200
# hotdogs: 200-250
# hotdogs: 250-300
# hotdogs: 300-350
# hotdogs: 350-400
# hotdogs: 400-450
# hotdogs: 450-500
# hotdogs: 500-550
# hotdogs: 550-600
# hotdogs: 600-650
# hotdogs: 650-700
# hotdogs: 700-750
# hotdogs: 750-800
# hotdogs: 800-850
# hotdogs: 850-900
# hotdogs: 900-950
# hotdogs: 950-1000
# filipino: 0-50
# fishnchips: 0-50
# fishnchips: 50-100
# fishnchips: 100-150
# fishnchips: 150-200
# fishnchips: 200-250
# fishnchips: 250-300
# fondue: 0-50
# food_court: 0-50
# foodstands: 0-50
# foodstands: 50-100
# foodstands: 100-150
# french: 0-50
# french: 50-100
# french: 100-150
# french: 150-200
# french: 200-250
# french: 250-300
# french: 300-350
# gastropubs: 0-50
# gastropubs: 50-100
# gastropubs: 100-150
# gastropubs: 150-200
# german: 0-50
# gluten_free: 0-50
# greek: 0-50
# greek: 50-100
# greek: 100-150
# halal: 0-50
# halal: 50-100
# halal: 100-150
# hawaiian: 0-50
# himalayan: 0-50
# hotdog: 0-50
# hungarian: 0-50
# indpak: 0-50
# indpak: 50-100
# indpak: 100-150
# indpak: 150-200
# indpak: 200-250
# indpak: 250-300
# indpak: 300-350
# indpak: 350-400
# indpak: 400-450
# indpak: 450-500
# indpak: 500-550
# indpak: 550-600
# indpak: 600-650
# indpak: 650-700
# indpak: 700-750
# indpak: 750-800
# indpak: 800-850
# indpak: 850-900
# indonesian: 0-50
# irish: 0-50
# italian: 0-50
# italian: 50-100
# italian: 100-150
# italian: 150-200
# italian: 200-250
# italian: 250-300
# italian: 300-350
# italian: 350-400
# italian: 400-450
# italian: 450-500
# italian: 500-550
# italian: 550-600
# italian: 600-650
# italian: 650-700
# italian: 700-750
# italian: 750-800
# italian: 800-850
# italian: 850-900
# italian: 900-950
# italian: 950-1000
# japanese: 0-50
# japanese: 50-100
# japanese: 100-150
# japanese: 150-200
# japanese: 200-250
# japanese: 250-300
# japanese: 300-350
# japanese: 350-400
# japanese: 400-450
# japanese: 450-500
# japanese: 500-550
# ramen: 0-50
# korean: 0-50
# korean: 50-100
# kosher: 0-50
# laotian: 0-50
# latin: 0-50
# latin: 50-100
# raw_food: 0-50
# malaysian: 0-50
# malaysian: 50-100
# mediterranean: 0-50
# mediterranean: 50-100
# mediterranean: 100-150
# mediterranean: 150-200
# mediterranean: 200-250
# mediterranean: 250-300
# mediterranean: 300-350
# mediterranean: 350-400
# falafel: 0-50
# mexican: 0-50
# mexican: 50-100
# mexican: 100-150
# mexican: 150-200
# mideastern: 0-50
# mideastern: 50-100
# mideastern: 100-150
# mideastern: 150-200
# mideastern: 200-250
# mideastern: 250-300
# lebanese: 0-50
# lebanese: 50-100
# modern_european: 0-50
# modern_european: 50-100
# modern_european: 100-150
# modern_european: 150-200
# modern_european: 200-250
# modern_european: 250-300
# mongolian: 0-50
# moroccan: 0-50
# persian: 0-50
# persian: 50-100
# peruvian: 0-50
# pizza: 0-50
# pizza: 50-100
# pizza: 100-150
# pizza: 150-200
# pizza: 200-250
# pizza: 250-300
# pizza: 300-350
# pizza: 350-400
# pizza: 400-450
# pizza: 450-500
# pizza: 500-550
# pizza: 550-600
# pizza: 600-650
# pizza: 650-700
# pizza: 700-750
# pizza: 750-800
# polish: 0-50
# portuguese: 0-50
# portuguese: 50-100
# russian: 0-50
# salad: 0-50
# salad: 50-100
# salad: 100-150
# sandwiches: 0-50
# sandwiches: 50-100
# sandwiches: 100-150
# sandwiches: 150-200
# sandwiches: 200-250
# sandwiches: 250-300
# sandwiches: 300-350
# sandwiches: 350-400
# sandwiches: 400-450
# sandwiches: 450-500
# sandwiches: 500-550
# sandwiches: 550-600
# sandwiches: 600-650
# scandinavian: 0-50
# scottish: 0-50
# seafood: 0-50
# seafood: 50-100
# seafood: 100-150
# seafood: 150-200
# singaporean: 0-50
# soulfood: 0-50
# soup: 0-50
# southern: 0-50
# spanish: 0-50
# spanish: 50-100
# spanish: 100-150
# steak: 0-50
# steak: 50-100
# steak: 100-150
# steak: 150-200
# sushi: 0-50
# sushi: 50-100
# sushi: 100-150
# sushi: 150-200
# sushi: 200-250
# sushi: 250-300
# taiwanese: 0-50
# tapas: 0-50
# tapas: 50-100
# tapas: 100-150
# tapasmallplates: 0-50
# tapasmallplates: 50-100
# mex: 0-50
# mex: 50-100
# mex: 100-150
# mex: 150-200
# mex: 200-250
# mex: 250-300
# mex: 300-350
# mex: 350-400
# mex: 400-450
# mex: 450-500
# mex: 500-550
# mex: 550-600
# mex: 600-650
# mex: 650-700
# mex: 700-750
# mex: 750-800
# mex: 800-850
# mex: 850-900
# mex: 900-950
# mex: 950-1000
# thai: 0-50
# thai: 50-100
# thai: 100-150
# thai: 150-200
# thai: 200-250
# thai: 250-300
# thai: 300-350
# turkish: 0-50
# turkish: 50-100
# turkish: 100-150
# turkish: 150-200
# turkish: 200-250
# turkish: 250-300
# ukrainian: 0-50
# vegan: 0-50
# vegan: 50-100
# vegan: 100-150
# vegetarian: 0-50
# vegetarian: 50-100
# vegetarian: 100-150
# vietnamese: 0-50
# vietnamese: 50-100
# vietnamese: 100-150
# vietnamese: 150-200

# %%
Yelp_listing = [i for n, i in enumerate(yelp_restaurants) if i not in yelp_restaurants[n + 1:]]

# %%
london_restaurants = sorted(Yelp_listing, key=lambda k: k['name'])

# %%
london_restaurants
# Out:
# [{'id': '82I-SlGojUpp7Rzotmv9lg',
#   'alias': 'and-pasta-london',
#   'name': '&Pasta',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Sg5RIATW38Zx_sL8mxpRxA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/and-pasta-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 5,
#   'categories': [{'alias': 'delis', 'title': 'Delis'},
#    {'alias': 'italian', 'title': 'Italian'},
#    {'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 51.5128615, 'longitude': -0.1320778},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '60 Dean Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W1D 6AW',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['60 Dean Street', 'London W1D 6AW', 'United Kingdom']},
#   'phone': '+44207346955',
#   'display_phone': '+44 207346955',
#   'distance': 268.377274931195},
#  {'id': 'zGSyCNHv2RKiEHRgVimVJg',
#   'alias': 'and-feast-london',
#   'name': '&feast',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/and-feast-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 1,
#   'categories': [{'alias': 'buffets', 'title': 'Buffets'},
#    {'alias': 'salad', 'title': 'Salad'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 51.474195279101,
#    'longitude': -0.244207631126528},
#   'transactions': [],
#   'location': {'address1': '57A Church Road',
#    'address2': '',
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'SW13 9HH',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['57A Church Road',
#     'London SW13 9HH',
#     'United Kingdom']},
#   'phone': '+442087487000',
#   'display_phone': '+44 20 8748 7000',
#   'distance': 8638.589329520311},
#  {'id': 'ghg0SAC1cuKkk46ji-M9Kw',
#   'alias': 'the-black-lab-coffee-house-london',
#   'name': "'The Black Lab' Coffee House",
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/e_hPHnpzTNA0ezHfxHGFiA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/the-black-lab-coffee-house-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 43,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'juicebars', 'title': 'Juice Bars & Smoothies'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.4610903556983,
#    'longitude': -0.138673064112254},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '18 Clapham Common South Side',
#    'address2': '',
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'SW4 7AB',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['18 Clapham Common South Side',
#     'London SW4 7AB',
#     'United Kingdom']},
#   'phone': '+442077388441',
#   'display_phone': '+44 20 7738 8441',
#   'distance': 5756.8687201302955},
#  {'id': '6hfGUw2-80sTXNvhijOtEQ',
#   'alias': '65-plus-six-five-supper-club-london',
#   'name': '+65 / Plus-Six-Five Supper Club',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7owAGoVrgOq5_EPzSDwLbg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/65-plus-six-five-supper-club-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 1,
#   'categories': [{'alias': 'singaporean', 'title': 'Singaporean'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 51.5324593, 'longitude': -0.1062},
#   'transactions': [],
#   'location': {'address1': 'Angel',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'N1',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['Angel', 'London N1', 'United Kingdom']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 3028.595896906563},
#  {'id': '08H7ypKfwASXosKQcTT6RA',
#   'alias': '1-blossom-street-london',
#   'name': '1 Blossom Street',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/K8Di7hOyfMtx2HQbSK_UOQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/1-blossom-street-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 1,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 51.5210593, 'longitude': -0.0777606},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '1 Blossom Street',
#    'address2': None,
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'E1 6BX',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['1 Blossom Street', 'London E1 6BX', 'United Kingdom']},
#   'phone': '+442072476530',
#   'display_phone': '+44 20 7247 6530',
#   'distance': 4129.321716984232},
#  {'id': 'f0nNAgUfOE68tmSQsx4dnw',
#   'alias': '1-lombard-street-london-4',
#   'name': '1 Lombard Street',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/fwE7zSBFrDk0OrBo5SaM1A/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/1-lombard-street-london-4?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 33,
#   'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 51.513104358145,
#    'longitude': -0.0888951488025643},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '1 Lombard Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'EC3V 9AA',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['1 Lombard Street',
#     'London EC3V 9AA',
#     'United Kingdom']},
#   'phone': '+442079296611',
#   'display_phone': '+44 20 7929 6611',
#   'distance': 3256.7674889740624},
#  {'id': 'PEgAoJeVtVAbmuNKUWa-wg',
#   'alias': '10-greek-street-london',
#   'name': '10 Greek Street',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-88bKhhTr5nVtN6hxERGlA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/10-greek-street-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 51,
#   'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.5144981659116,
#    'longitude': -0.131063461303711},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '10 Greek Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W1D 4DH',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['10 Greek Street', 'London W1D 4DH', 'United Kingdom']},
#   'phone': '+442077344677',
#   'display_phone': '+44 20 7734 4677',
#   'distance': 385.73947726767943},
#  {'id': 'GT6FIs31nbN02R0f3K52MQ',
#   'alias': '100-wardour-st-soho-2',
#   'name': '100 Wardour St',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/3uvZaSUp9eQc-5FoMjHIqA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/100-wardour-st-soho-2?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 13,
#   'categories': [{'alias': 'danceclubs', 'title': 'Dance Clubs'},
#    {'alias': 'lounges', 'title': 'Lounges'},
#    {'alias': 'british', 'title': 'British'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 51.5136011797847,
#    'longitude': -0.133917666971684},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '100 Wardour Street',
#    'address2': '',
#    'address3': '',
#    'city': 'Soho',
#    'zip_code': 'W1F 0TN',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['100 Wardour Street',
#     'Soho W1F 0TN',
#     'United Kingdom']},
#   'phone': '+442073144000',
#   'display_phone': '+44 20 7314 4000',
#   'distance': 164.74429869881257},
#  {'id': 'ZRI9ixMTvEfICdRFmFcuww',
#   'alias': '1001-nights-london',
#   'name': '1001 Nights',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/1001-nights-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'mideastern', 'title': 'Middle Eastern'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 51.506198, 'longitude': -0.14444},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '85 Piccadilly',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W1J 7NB',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['85 Piccadilly', 'London W1J 7NB', 'United Kingdom']},
#   'phone': '+442076294440',
#   'display_phone': '+44 20 7629 4440',
#   'distance': 943.1234848800545},
#  {'id': '4vNnh5EEXwrSvdeB89WGTg',
#   'alias': '101-thai-kitchen-london',
#   'name': '101 Thai Kitchen',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/1tOL34mLmog63aBrPq28DQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/101-thai-kitchen-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 24,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.4936071, 'longitude': -0.2440391},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '352 King Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W6 0RX',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['352 King Street', 'London W6 0RX', 'United Kingdom']},
#   'phone': '+442087466888',
#   'display_phone': '+44 20 8746 6888',
#   'distance': 7785.819007468829},
#  {'id': '1NOMO_ZuYy1u57lKSp1tSw',
#   'alias': '108-brasserie-london',
#   'name': '108 Brasserie',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7bsolsvZdcnN4FHIfJMAwA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/108-brasserie-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 35,
#   'categories': [{'alias': 'british', 'title': 'British'},
#    {'alias': 'modern_european', 'title': 'Modern European'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.5179613, 'longitude': -0.1505703},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '108 Marylebone Lane',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W1U 2QE',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['108 Marylebone Lane',
#     'London W1U 2QE',
#     'United Kingdom']},
#   'phone': '+442079693900',
#   'display_phone': '+44 20 7969 3900',
#   'distance': 1162.5013377145387},
#  {'id': 'BRzP-TB3SfFUXiEp8HJb2g',
#   'alias': '108-garage-london',
#   'name': '108 Garage',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/fRm6rBc5tQa_Hqex7nFMng/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/108-garage-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 7,
#   'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.521322, 'longitude': -0.209515},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '108 Golborne Road',
#    'address2': '',
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'W10 5PS',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['108 Golborne Road',
#     'London W10 5PS',
#     'United Kingdom']},
#   'phone': '+442089693769',
#   'display_phone': '+44 20 8969 3769',
#   'distance': 5176.62376570631},
#  {'id': 'Huv5RTpVqcgaib3eBuIQ4A',
#   'alias': '120-central-london',
#   'name': '120 Central',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/0pUl0g1kORnablWoDS4akw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/120-central-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 1,
#   'categories': [{'alias': 'brasseries', 'title': 'Brasseries'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 51.5274622403177,
#    'longitude': -0.0961238304820378},
#   'transactions': [],
#   'location': {'address1': '120 Central Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'EC1V 8DS',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['120 Central Street',
#     'London EC1V 8DS',
#     'United Kingdom']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 3200.0898986313623},
#  {'id': 'C0JknZTBtdxY0-S-RxMWsA',
#   'alias': '129-hrd-london-3',
#   'name': '129 HRD',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LYeQPCdDD6PkmCoEa8CVLg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/129-hrd-london-3?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'british', 'title': 'British'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 51.5486522, 'longitude': -0.1074633},
#   'transactions': [],
#   'location': {'address1': '129 Holloway Road',
#    'address2': '',
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'N7 8LT',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['129 Holloway Road',
#     'London N7 8LT',
#     'United Kingdom']},
#   'phone': '+442036387322',
#   'display_phone': '+44 20 3638 7322',
#   'distance': 4443.63618622649},
#  {'id': '0OM26VH2DMNU212HWjyGtA',
#   'alias': '12-51-james-cochran-n1-london',
#   'name': '12:51 James Cochran N1',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/VeghTbZCMuRfYyxv9eMD3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/12-51-james-cochran-n1-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'british', 'title': 'British'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.5379328, 'longitude': -0.1029584},
#   'transactions': [],
#   'location': {'address1': '107 Upper Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'N1 1QN',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['107 Upper Street', 'London N1 1QN', 'United Kingdom']},
#   'phone': '+447934202269',
#   'display_phone': '+44 7934 202269',
#   'distance': 3605.4412190115445},
#  {'id': 'jaw3GxHkmQf0x5UeCz676g',
#   'alias': '16mm-london',
#   'name': '16mm',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kk66EEz8AXI2ClmECH74sg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/16mm-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 4,
#   'categories': [{'alias': 'movietheaters', 'title': 'Cinema'},
#    {'alias': 'british', 'title': 'British'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.514366, 'longitude': -0.136631},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': "19 D'Arblay St",
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W1F 8ED',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ["19 D'Arblay St", 'London W1F 8ED', 'United Kingdom']},
#   'phone': '+442072878892',
#   'display_phone': '+44 20 7287 8892',
#   'distance': 175.32094152780581},
#  {'id': 'MsT-tFXhvd1xx3wxNdVC_g',
#   'alias': '17-air-street-london',
#   'name': '17 Air Street',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/17-air-street-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 1.0,
#   'coordinates': {'latitude': 51.5106815, 'longitude': -0.1368123},
#   'transactions': [],
#   'location': {'address1': '17 Air Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W1B 5AF',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['17 Air Street', 'London W1B 5AF', 'United Kingdom']},
#   'phone': '+442032877959',
#   'display_phone': '+44 20 3287 7959',
#   'distance': 246.7407054559077},
#  {'id': 'qwm4fn-m7KKHXbfmM9J_Tg',
#   'alias': '189-piccadilly-london',
#   'name': '189 Piccadilly',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/Jd5WN9c9utKVcBl4ufUYIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/189-piccadilly-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 8,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 51.5085791, 'longitude': -0.137928},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '189 Piccadilly',
#    'address2': '',
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'W1J 9ES',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['189 Piccadilly', 'London W1J 9ES', 'United Kingdom']},
#   'phone': '+442074341921',
#   'display_phone': '+44 20 7434 1921',
#   'distance': 492.57793859695323},
#  {'id': 'zPCKI2wkBuZpJKAF7xtqYA',
#   'alias': '19-numara-bos-cirrik-2-london',
#   'name': '19 Numara Bos Cirrik 2',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ldnOuDhJ9qGLAHDTIMlmeA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/19-numara-bos-cirrik-2-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 12,
#   'categories': [{'alias': 'turkish', 'title': 'Turkish'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.5621117, 'longitude': -0.0734442},
#   'transactions': [],
#   'price': '£',
#   'location': {'address1': '194 Stoke Newington High St',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'N16 7JD',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['194 Stoke Newington High St',
#     'London N16 7JD',
#     'United Kingdom']},
#   'phone': '+442072499111',
#   'display_phone': '+44 20 7249 9111',
#   'distance': 6994.715240155146},
#  {'id': 'YfBp4aufA9hMbMUXyOm7LA',
#   'alias': '1901-restaurant-london',
#   'name': '1901 Restaurant',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/VjNebEIgBwr-6sOIZ390zA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/1901-restaurant-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 17,
#   'categories': [{'alias': 'british', 'title': 'British'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.5172135, 'longitude': -0.0813499},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '40 Liverpool Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'EC2M 7QN',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['40 Liverpool Street',
#     'London EC2M 7QN',
#     'United Kingdom']},
#   'phone': '+442076187008',
#   'display_phone': '+44 20 7618 7008',
#   'distance': 3805.265130812822},
#  {'id': 'k26QQDySxt37YkpeJmrR2w',
#   'alias': '1910-mexican-kitchen-london',
#   'name': '1910 Mexican Kitchen',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/1910-mexican-kitchen-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 51.5091705, 'longitude': -0.22185},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': 'Westfield London Shopping Centre',
#    'address2': 'Ariel Way',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W12 7GF',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['Westfield London Shopping Centre',
#     'Ariel Way',
#     'London W12 7GF',
#     'United Kingdom']},
#   'phone': '+442087498222',
#   'display_phone': '+44 20 8749 8222',
#   'distance': 6005.786951470072},
#  {'id': 'CUBjGkG29s0V7yPnr-5Hwg',
#   'alias': '1920-london-2',
#   'name': '1920',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-6F65plcR9A3g9Cb23Egwg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/1920-london-2?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 9,
#   'categories': [{'alias': 'poolhalls', 'title': 'Pool Halls'},
#    {'alias': 'burgers', 'title': 'Burgers'},
#    {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.5232200622559,
#    'longitude': -0.100608997046947},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '19-20 Great Sutton Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'EC1V 0DR',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['19-20 Great Sutton Street',
#     'London EC1V 0DR',
#     'United Kingdom']},
#   'phone': '+442072531920',
#   'display_phone': '+44 20 7253 1920',
#   'distance': 2704.6353982562073},
#  {'id': 'v_f7AyRPsUfzeXch8YIyOQ',
#   'alias': '197-chiswick-fire-station-london-4',
#   'name': '197 Chiswick Fire Station',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/FKz0msYO5Rcy9b3_xKPlZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/197-chiswick-fire-station-london-4?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 10,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'british', 'title': 'British'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.4922094, 'longitude': -0.2574755},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '197-199 Chiswick High Road',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W4 2DR',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['197-199 Chiswick High Road',
#     'London W4 2DR',
#     'United Kingdom']},
#   'phone': '+442038574669',
#   'display_phone': '+44 20 3857 4669',
#   'distance': 8718.260572072251},
#  {'id': 'Sd0gAH-3xVBKs-C5Lz4y0A',
#   'alias': '1997-london',
#   'name': '1997',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/kNABvGwxpgjRIO8ZWocdfA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/1997-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 8,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 51.5108773, 'longitude': -0.1319364},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '19 Wardour Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W1D 6PF',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['19 Wardour Street',
#     'London W1D 6PF',
#     'United Kingdom']},
#   'phone': '+442077342868',
#   'display_phone': '+44 20 7734 2868',
#   'distance': 338.9673799233641},
#  {'id': 'ytTm9n-yKZo3TFbAQqYmVQ',
#   'alias': '1n1-fashion-pizza-london',
#   'name': '1n1 Fashion Pizza',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/1n1-fashion-pizza-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#    {'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'fashion', 'title': 'Fashion'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 51.5159868443128,
#    'longitude': -0.0759759172797203},
#   'transactions': [],
#   'location': {'address1': '56 Middlesex Street',
#    'address2': '',
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'E1',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['56 Middlesex Street', 'London E1', 'United Kingdom']},
#   'phone': '+44447763253340',
#   'display_phone': '+44 447763253340',
#   'distance': 4165.284254733514},
#  {'id': 'zaRX4cnAUf39W3jsZmUa4w',
#   'alias': '2-amici-london',
#   'name': '2 Amici',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/zeIIiN4ClQz4avE1OaKAvA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/2-amici-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 12,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.4947341, 'longitude': -0.1365664},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '48a Rochester Row',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'SW1P 1JU',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['48a Rochester Row',
#     'London SW1P 1JU',
#     'United Kingdom']},
#   'phone': '+442079765660',
#   'display_phone': '+44 20 7976 5660',
#   'distance': 2012.8263697580032},
#  {'id': 'f_mao4gWf5dKqMw-ZWpErQ',
#   'alias': '2-sisters-tandoori-london',
#   'name': '2 Sisters Tandoori',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/9z-fQ0UXhh1FH2DWP9xHhg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/2-sisters-tandoori-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'},
#    {'alias': 'indpak', 'title': 'Indian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.4684605, 'longitude': -0.0527638},
#   'transactions': [],
#   'location': {'address1': '4 Gibbon Road',
#    'address2': 'Nunhead',
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'SE15 2AS',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['4 Gibbon Road',
#     'Nunhead',
#     'London SE15 2AS',
#     'United Kingdom']},
#   'phone': '+442072777635',
#   'display_phone': '+44 20 7277 7635',
#   'distance': 7584.320664030244},
#  {'id': 'j5N5Foo455q3yYL62TMQ7A',
#   'alias': '2-veneti-london',
#   'name': '2 Veneti',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/7cuh-F0NTlYVFxcKMJovIg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/2-veneti-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 15,
#   'categories': [{'alias': 'italian', 'title': 'Italian'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.516872, 'longitude': -0.146676},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '8-10 Wigmore Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W1U 2RD',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['8-10 Wigmore Street',
#     'London W1U 2RD',
#     'United Kingdom']},
#   'phone': '+442076370789',
#   'display_phone': '+44 20 7637 0789',
#   'distance': 860.4295027802729},
#  {'id': 'qiPyfYCQ3ohGoIEzUysUeg',
#   'alias': '203-restaurant-and-wine-bar-london',
#   'name': '203 Restaurant & Wine Bar',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/xmhSsAXPV4oS1VfSLpqOAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/203-restaurant-and-wine-bar-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'sportsbars', 'title': 'Sports Bars'},
#    {'alias': 'african', 'title': 'African'},
#    {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.4282852, 'longitude': -0.1307875},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '203 Streatham High Road',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'SW16 6EG',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['203 Streatham High Road',
#     'London SW16 6EG',
#     'United Kingdom']},
#   'phone': '+442086770003',
#   'display_phone': '+44 20 8677 0003',
#   'distance': 9408.369337233886},
#  {'id': 'VMwN6XcaM0lqxmVTgDjiZw',
#   'alias': '215-hackney-london',
#   'name': '215 Hackney',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/aXyQ7KkyhJjRdSrU1w0Wpw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/215-hackney-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 51.5633164536417,
#    'longitude': -0.0734727457165718},
#   'transactions': [],
#   'location': {'address1': '215 Stoke Newington High Street',
#    'address2': '',
#    'address3': 'Hackney',
#    'city': 'London',
#    'zip_code': 'N16 0LH',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['215 Stoke Newington High Street',
#     'Hackney',
#     'London N16 0LH',
#     'United Kingdom']},
#   'phone': '+44442072542999',
#   'display_phone': '+44 442072542999',
#   'distance': 7084.028416047258},
#  {'id': '8f1KBWM2h4h47mq7K_2YMA',
#   'alias': '22-north-street-london',
#   'name': '22 North Street',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/JmrCYQKCrNYfVrC_knqbSw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/22-north-street-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 1,
#   'categories': [{'alias': 'modern_european', 'title': 'Modern European'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 51.464281, 'longitude': -0.1411732},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '22 North Street',
#    'address2': 'Clapham Old Town',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'SW4 0HB',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['22 North Street',
#     'Clapham Old Town',
#     'London SW4 0HB',
#     'United Kingdom']},
#   'phone': '+442035833702',
#   'display_phone': '+44 20 3583 3702',
#   'distance': 5411.081984623013},
#  {'id': 'R4yaSL1PT2mpt5yNX2U7AA',
#   'alias': '222-veggie-vegan-london',
#   'name': '222 Veggie Vegan',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/paqDXKodJkGpfFsxtRRJJQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/222-veggie-vegan-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 85,
#   'categories': [{'alias': 'vegetarian', 'title': 'Vegetarian'},
#    {'alias': 'vegan', 'title': 'Vegan'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.486007, 'longitude': -0.2030859},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '222 North End Road',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W14 9NU',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['222 North End Road',
#     'London W14 9NU',
#     'United Kingdom']},
#   'phone': '+442073812322',
#   'display_phone': '+44 20 7381 2322',
#   'distance': 5514.93243716084},
#  {'id': 'Lr5_1a2rIyzA7W-6UPKS-A',
#   'alias': '26-grains-london',
#   'name': '26 Grains',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Ci9nQvD05RdQ7k56unmJwQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/26-grains-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 74,
#   'categories': [{'alias': 'coffee', 'title': 'Coffee & Tea'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.5143765, 'longitude': -0.126556},
#   'transactions': [],
#   'price': '£',
#   'location': {'address1': "1 Neal's Yard",
#    'address2': 'Covent Garden',
#    'address3': 'Seven Dials',
#    'city': 'London',
#    'zip_code': 'WC2H 9DP',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ["1 Neal's Yard",
#     'Covent Garden',
#     'Seven Dials',
#     'London WC2H 9DP',
#     'United Kingdom']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 672.6546229251097},
#  {'id': 'pKebVZTdbgx7kI89vDMERw',
#   'alias': '28-church-row-hampstead',
#   'name': '28 Church Row',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/28-church-row-hampstead?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 1,
#   'categories': [{'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 51.5554943529702,
#    'longitude': -0.178899871641582},
#   'transactions': [],
#   'location': {'address1': '28 Church Row',
#    'address2': '',
#    'address3': None,
#    'city': 'HAMPSTEAD',
#    'zip_code': 'NW3 6UP',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['28 Church Row',
#     'HAMPSTEAD NW3 6UP',
#     'United Kingdom']},
#   'phone': '+442079932062',
#   'display_phone': '+44 20 7993 2062',
#   'distance': 5596.72735217849},
#  {'id': 'jdtQiQnWOuUq3uqNwc1nRw',
#   'alias': '28-west-bar-and-grill-london',
#   'name': '28 West Bar & Grill',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/jrHsBG7gNfi9sAuw9dZdvw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/28-west-bar-and-grill-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 5,
#   'categories': [{'alias': 'british', 'title': 'British'},
#    {'alias': 'bars', 'title': 'Bars'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 51.5053510373734,
#    'longitude': -0.0279881193267784},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '28 Westferry Circus',
#    'address2': None,
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'E14 8RR',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['28 Westferry Circus',
#     'London E14 8RR',
#     'United Kingdom']},
#   'phone': '+442037576664',
#   'display_phone': '+44 20 3757 6664',
#   'distance': 7518.2781591667845},
#  {'id': 'E7_ioBksqj-go2Sky9N3iw',
#   'alias': '28-50-london',
#   'name': '28-50',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/1ChUA-eGfXmGWEi60RIvqA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/28-50-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 15,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'french', 'title': 'French'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.514634764735, 'longitude': -0.10980056506839},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '140 Fetter Lane',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'EC4A 1BT',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['140 Fetter Lane',
#     'London EC4A 1BT',
#     'United Kingdom']},
#   'phone': '+442072428877',
#   'display_phone': '+44 20 7242 8877',
#   'distance': 1820.9545960576113},
#  {'id': 'tyZUHo1ZYXJAZuXSY9Mnfg',
#   'alias': '28-50-maddox-street-london',
#   'name': '28-50 Maddox Street',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/kdofbiwNjxMAeOUFfajWZA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/28-50-maddox-street-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 5,
#   'categories': [{'alias': 'british', 'title': 'British'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.5131068, 'longitude': -0.1417726},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '17-19 Maddox Street',
#    'address2': 'Mayfair',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W1S 2QH',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['17-19 Maddox Street',
#     'Mayfair',
#     'London W1S 2QH',
#     'United Kingdom']},
#   'phone': '+442074951505',
#   'display_phone': '+44 20 7495 1505',
#   'distance': 403.65451740261267},
#  {'id': 'mM13I6b3emWA8KthSxmXYg',
#   'alias': '28-50-wine-workshop-and-kitchen-london',
#   'name': '28-50 Wine Workshop and Kitchen',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/tGWEKtKr6B1Bm48g-UIG3w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/28-50-wine-workshop-and-kitchen-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 37,
#   'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#    {'alias': 'modern_european', 'title': 'Modern European'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.516357, 'longitude': -0.150488},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '15-17 Marylebone Lane',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W1U 2NE',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['15-17 Marylebone Lane',
#     'London W1U 2NE',
#     'United Kingdom']},
#   'phone': '+442074867922',
#   'display_phone': '+44 20 7486 7922',
#   'distance': 1075.8878616539794},
#  {'id': 'aXYdIvaWPoibnymrEcy1rw',
#   'alias': '2k-steakhouse-london',
#   'name': '2K Steakhouse',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/s36DmRvEDIbNdo2fbk60dg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/2k-steakhouse-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 3,
#   'categories': [{'alias': 'argentine', 'title': 'Argentine'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.5433273066916,
#    'longitude': -0.0907927751541138},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '326 Essex Road',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'N1 3PB',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['326 Essex Road', 'London N1 3PB', 'United Kingdom']},
#   'phone': '+442073540300',
#   'display_phone': '+44 20 7354 0300',
#   'distance': 4610.507818714171},
#  {'id': '_IMmOzEbegglpryBu_IeGA',
#   'alias': '3-south-place-london-2',
#   'name': '3 South Place',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gWJmBBGgRaidli9JtcmbfA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/3-south-place-london-2?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 18,
#   'categories': [{'alias': 'british', 'title': 'British'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.519045, 'longitude': -0.086526},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '3 South Place',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'EC2M 2AF',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['3 South Place', 'London EC2M 2AF', 'United Kingdom']},
#   'phone': '+442032151270',
#   'display_phone': '+44 20 3215 1270',
#   'distance': 3497.2001428117433},
#  {'id': 'nnn6-0MRprBm3UIXflXz5g',
#   'alias': '32-cafe-coleman-london',
#   'name': '32 Cafe Coleman',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/yAGoku5AvL-cMlP-Sns2VA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/32-cafe-coleman-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 3,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 51.5156517028809,
#    'longitude': -0.0901700034737587},
#   'transactions': [],
#   'location': {'address1': '32-34 Coleman Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'EC2R 5AN',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['32-34 Coleman Street',
#     'London EC2R 5AN',
#     'United Kingdom']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 3183.758292088836},
#  {'id': 'nyLKZw4j3Qi066s-Z7mG9w',
#   'alias': '34-mayfair-london',
#   'name': '34 Mayfair',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/FcB83vFaB4_H_FrB1g_4Kg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/34-mayfair-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 32,
#   'categories': [{'alias': 'steak', 'title': 'Steakhouses'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'modern_european', 'title': 'Modern European'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.5105548, 'longitude': -0.1525879},
#   'transactions': [],
#   'price': '££££',
#   'location': {'address1': '34 Grovesnor Square',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W1K 2HD',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['34 Grovesnor Square',
#     'London W1K 2HD',
#     'United Kingdom']},
#   'phone': '+442033503434',
#   'display_phone': '+44 20 3350 3434',
#   'distance': 1163.4996128445885},
#  {'id': 'r9WDG-yHwzimEe10gR88Fg',
#   'alias': '39-steps-coffee-london',
#   'name': '39 Steps Coffee',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/_9YteXr-jIFUECyJ53yuuA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/39-steps-coffee-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 6,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 51.5137938420751,
#    'longitude': -0.135145469921005},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': "8 D'Arblay St",
#    'address2': '',
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'W1F 8DP',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ["8 D'Arblay St", 'London W1F 8DP', 'United Kingdom']},
#   'phone': '+442072876682',
#   'display_phone': '+44 20 7287 6682',
#   'distance': 120.41421495607376},
#  {'id': '1xOGuRkmfEd-j8Avs4-MuQ',
#   'alias': '3b-london',
#   'name': '3B',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/DtaXM5_QzixASCZdZz8NQg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/3b-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 1,
#   'categories': [{'alias': 'spanish', 'title': 'Spanish'},
#    {'alias': 'basque', 'title': 'Basque'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 51.5170479, 'longitude': -0.188208},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '43 Porchester Road',
#    'address2': None,
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'W2 5DP',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['43 Porchester Road',
#     'London W2 5DP',
#     'United Kingdom']},
#   'phone': '+442077925885',
#   'display_phone': '+44 20 7792 5885',
#   'distance': 3645.9435898206416},
#  {'id': '7nEKgNbtwWorvpQGgt66iA',
#   'alias': '400-rabbits-london',
#   'name': '400 Rabbits',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/znCtKawQUVSMZlm1W0o78Q/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/400-rabbits-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 4,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 51.4657983, 'longitude': -0.0573341},
#   'transactions': [],
#   'location': {'address1': '143 Evelina Road',
#    'address2': '',
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'SE15 3HB',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['143 Evelina Road',
#     'London SE15 3HB',
#     'United Kingdom']},
#   'phone': '+442071324150',
#   'display_phone': '+44 20 7132 4150',
#   'distance': 7545.869529422811},
#  {'id': 'zJU95jzTNozpLS1o4G4gng',
#   'alias': '45-jermyn-st-london',
#   'name': '45 Jermyn St',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/x_Xa3CtKc13u3XHV05UYwg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/45-jermyn-st-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 28,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#    {'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.5079725931959,
#    'longitude': -0.138294799999976},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '45 Jermyn Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'SW1Y 6JD',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['45 Jermyn Street',
#     'London SW1Y 6JD',
#     'United Kingdom']},
#   'phone': '+442072054545',
#   'display_phone': '+44 20 7205 4545',
#   'distance': 564.4403893057505},
#  {'id': 'LyXXTUzll212_JKMkzC3DQ',
#   'alias': '49-cafe-london',
#   'name': '49 Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/6LDkY5E7uUbQdDGWNgSatQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/49-cafe-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 39,
#   'categories': [{'alias': 'modern_european', 'title': 'Modern European'},
#    {'alias': 'british', 'title': 'British'},
#    {'alias': 'cafes', 'title': 'Cafes'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.5249587, 'longitude': -0.1251605},
#   'transactions': [],
#   'price': '£',
#   'location': {'address1': '49 Marchmont Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'WC1N 1AP',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['49 Marchmont Street',
#     'London WC1N 1AP',
#     'United Kingdom']},
#   'phone': '+442035383474',
#   'display_phone': '+44 20 3538 3474',
#   'distance': 1541.1440285471679},
#  {'id': 'kLzKpF_ANHEC1tQNQInSuw',
#   'alias': '50-kalo-london',
#   'name': '50 Kalo',
#   'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/C2W7A1b5ZqO6QA4NKAhIvQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/50-kalo-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 9,
#   'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 51.5071183181121,
#    'longitude': -0.126525834202766},
#   'transactions': [],
#   'location': {'address1': '7 Northumberland Avenue',
#    'address2': '',
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'WC2N 5BY',
#    'country': 'GB',
#    'state': 'XGL',
# ...
#    'longitude': -0.231049607719115},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '13 Lower Mall',
#    'address2': 'Hammersmith',
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'W6 9DJ',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['13 Lower Mall',
#     'Hammersmith',
#     'London W6 9DJ',
#     'United Kingdom']},
#   'phone': '+442087485774',
#   'display_phone': '+44 20 8748 5774',
#   'distance': 7073.988584862386},
#  {'id': 'QXdZguo_cKzAADNSyU71zQ',
#   'alias': 'blue-anchor-fish-bar-london',
#   'name': 'Blue Anchor Fish Bar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/329ZkFTAxpTY0FQgRYCVTg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-anchor-fish-bar-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'},
#    {'alias': 'british', 'title': 'British'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.49257694374, 'longitude': -0.062775401871988},
#   'transactions': [],
#   'location': {'address1': '49 Blue Anchor Lane',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'SE16 3UL',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['49 Blue Anchor Lane',
#     'London SE16 3UL',
#     'United Kingdom']},
#   'phone': '+442072373696',
#   'display_phone': '+44 20 7237 3696',
#   'distance': 5543.594581497835},
#  {'id': 'p-hnrDekxxK1AuQj3iQ-Ug',
#   'alias': 'blue-boar-london-2',
#   'name': 'Blue Boar',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cev92Xz3uebEA1cxQCsitw/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-boar-london-2?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 61,
#   'categories': [{'alias': 'bars', 'title': 'Bars'},
#    {'alias': 'british', 'title': 'British'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 51.4995596, 'longitude': -0.1324751},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '45 Tothill Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'SW1H 9LQ',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['45 Tothill Street',
#     'London SW1H 9LQ',
#     'United Kingdom']},
#   'phone': '+442033011400',
#   'display_phone': '+44 20 3301 1400',
#   'distance': 1498.9370156504717},
#  {'id': 'swRWaoYcnQFS6yQ4RMhuhg',
#   'alias': 'blue-door-bistro-london',
#   'name': 'Blue Door Bistro',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/y7k9CaR3Wok0MpFtMTLlAQ/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-door-bistro-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 17,
#   'categories': [{'alias': 'british', 'title': 'British'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.5202164, 'longitude': -0.1257102},
#   'transactions': [],
#   'price': '£££',
#   'location': {'address1': '15 Montague Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'WC1B 5BJ',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['15 Montague Street',
#     'London WC1B 5BJ',
#     'United Kingdom']},
#   'phone': '+442076128416',
#   'display_phone': '+44 20 7612 8416',
#   'distance': 1085.0053178608703},
#  {'id': 'ta-X4-uw_eRXc4IX3u_euQ',
#   'alias': 'blue-ginger-london',
#   'name': 'Blue Ginger',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/tDGJDSPgxZeATFpZnKUkAg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-ginger-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 2.0,
#   'coordinates': {'latitude': 51.5224415, 'longitude': -0.1935969},
#   'transactions': [],
#   'location': {'address1': '328 Harrow Road',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W9 2HP',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['328 Harrow Road', 'London W9 2HP', 'United Kingdom']},
#   'phone': '+442072864982',
#   'display_phone': '+44 20 7286 4982',
#   'distance': 4127.299637610025},
#  {'id': 'lUuHAjSZuIm7kr66jwXATA',
#   'alias': 'blue-junction-morden-3',
#   'name': 'Blue Junction',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/msl15I5FvDSpqEOWiiVupg/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-junction-morden-3?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 5,
#   'categories': [{'alias': 'indpak', 'title': 'Indian'},
#    {'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.4015503338048,
#    'longitude': -0.196422278180466},
#   'transactions': [],
#   'location': {'address1': '1 Crown Lane',
#    'address2': None,
#    'address3': None,
#    'city': 'Morden',
#    'zip_code': 'SM4 5BY',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['1 Crown Lane', 'Morden SM4 5BY', 'United Kingdom']},
#   'phone': '+442085402583',
#   'display_phone': '+44 20 8540 2583',
#   'distance': 13064.285396898678},
#  {'id': 'sIeHJeTrsQFQChnGU0N2aA',
#   'alias': 'blue-lagoon-london',
#   'name': 'Blue Lagoon',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-lagoon-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 7,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 2.5,
#   'coordinates': {'latitude': 51.509221, 'longitude': -0.132057},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '23 Haymarket',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'SW1Y 4DG',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['23 Haymarket', 'London SW1Y 4DG', 'United Kingdom']},
#   'phone': '+442079307800',
#   'display_phone': '+44 20 7930 7800',
#   'distance': 485.41910119163134},
#  {'id': '_oGFNNazFkKZ_V2xabwm4A',
#   'alias': 'blue-moon-london-4',
#   'name': 'Blue Moon',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-moon-london-4?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 1,
#   'categories': [{'alias': 'hotdogs', 'title': 'Fast Food'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 51.622542, 'longitude': -0.08947},
#   'transactions': [],
#   'location': {'address1': 'Firs Lane',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'N13 5QQ',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['Firs Lane', 'London N13 5QQ', 'United Kingdom']},
#   'phone': '+442088870877',
#   'display_phone': '+44 20 8887 0877',
#   'distance': 12624.105064173627},
#  {'id': 'KzHGkWuFgsl2qB6jd7qwaA',
#   'alias': 'blue-moon-cafe-london',
#   'name': 'Blue Moon Cafe',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/vXxnedJBbMqpz6M1KDhjKA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-moon-cafe-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 14,
#   'categories': [{'alias': 'thai', 'title': 'Thai'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 51.555989605497, 'longitude': -0.13889930639904},
#   'transactions': [],
#   'price': '£',
#   'location': {'address1': '134 Fortess Road',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'NW5 2HP',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['134 Fortess Road',
#     'London NW5 2HP',
#     'United Kingdom']},
#   'phone': '+442072678672',
#   'display_phone': '+44 20 7267 8672',
#   'distance': 4802.827164497201},
#  {'id': 'mnws_1EkvSRuEMe5jqlxgA',
#   'alias': 'blue-olive-london',
#   'name': 'Blue Olive',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-olive-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'greek', 'title': 'Greek'},
#    {'alias': 'copyshops', 'title': 'Printing Services'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 51.5000036, 'longitude': -0.1270045},
#   'transactions': [],
#   'location': {'address1': None,
#    'address2': None,
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'SW1P 3JX',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['London SW1P 3JX', 'United Kingdom']},
#   'phone': '+442084418222',
#   'display_phone': '+44 20 8441 8222',
#   'distance': 1555.536307131157},
#  {'id': 'nWRMqCb9wCWipcBWlCRkuQ',
#   'alias': 'blue-orchid-london-3',
#   'name': 'Blue Orchid',
#   'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Qqa_f8bln2eWGdxbKN_gew/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-orchid-london-3?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'chinese', 'title': 'Chinese'}],
#   'rating': 5.0,
#   'coordinates': {'latitude': 51.4677314, 'longitude': -0.1435303},
#   'transactions': [],
#   'location': {'address1': '70 North Street',
#    'address2': 'Romford',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'RM1 1DA',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['70 North Street',
#     'Romford',
#     'London RM1 1DA',
#     'United Kingdom']},
#   'phone': '+441708761763',
#   'display_phone': '+44 1708 761763',
#   'distance': 5042.686930597693},
#  {'id': '9UncLmEiGmHmQkerlXBpcQ',
#   'alias': 'blue-plate-london',
#   'name': 'Blue Plate',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/kf3vDNuufWuRNuPUX9vpwA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-plate-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 3,
#   'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#   'rating': 4.5,
#   'coordinates': {'latitude': 51.4927, 'longitude': -0.252125},
#   'transactions': [],
#   'location': {'address1': '85 Chiswick High Road',
#    'address2': 'Chiswick',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W4 2EF',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['85 Chiswick High Road',
#     'Chiswick',
#     'London W4 2EF',
#     'United Kingdom']},
#   'phone': '+442070961609',
#   'display_phone': '+44 20 7096 1609',
#   'distance': 8344.695074936832},
#  {'id': '40OSH0Qk2v2CG_JDex6SeQ',
#   'alias': 'blue-river-all-day-breakfast-london',
#   'name': 'Blue River All day Breakfast',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ddRDe3VdCAdGdgJa9ZCHbA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-river-all-day-breakfast-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 5,
#   'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.5,
#   'coordinates': {'latitude': 51.532469138371,
#    'longitude': -0.119718631356742},
#   'transactions': [],
#   'location': {'address1': '55-57 Northdown Street',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'N1 9BL',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['55-57 Northdown Street',
#     'London N1 9BL',
#     'United Kingdom']},
#   'phone': '',
#   'display_phone': '',
#   'distance': 2455.232212361668},
#  {'id': 'I67fyrnwjRUXwihhoCCLxg',
#   'alias': 'blue-sea-fish-bar-london-2',
#   'name': 'Blue Sea Fish Bar',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-sea-fish-bar-london-2?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 1,
#   'categories': [{'alias': 'fishnchips', 'title': 'Fish & Chips'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.549808, 'longitude': -0.152203},
#   'transactions': [],
#   'location': {'address1': '143 Queens Crescent',
#    'address2': 'West Kentish Town',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'NW5 4ED',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['143 Queens Crescent',
#     'West Kentish Town',
#     'London NW5 4ED',
#     'United Kingdom']},
#   'phone': '+442072672299',
#   'display_phone': '+44 20 7267 2299',
#   'distance': 4254.650595421406},
#  {'id': 'QDEoVn2HaSjDnEcBrWBeTA',
#   'alias': 'blue-and-orange-london',
#   'name': 'Blue and Orange',
#   'image_url': '',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/blue-and-orange-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 1,
#   'categories': [{'alias': 'employmentagencies',
#     'title': 'Employment Agencies'},
#    {'alias': 'mobilephones', 'title': 'Mobile Phones'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.5000036, 'longitude': -0.1270045},
#   'transactions': [],
#   'location': {'address1': None,
#    'address2': None,
#    'address3': None,
#    'city': 'London',
#    'zip_code': 'SW1P 3JX',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['London SW1P 3JX', 'United Kingdom']},
#   'phone': '+442086883142',
#   'display_phone': '+44 20 8688 3142',
#   'distance': 1555.536307131157},
#  {'id': 'i6Kjb1ndF4CIxqNOKGxqfg',
#   'alias': 'bluebell-bistro-london',
#   'name': 'Bluebell Bistro',
#   'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/twuRJWGcZKnDSxbulSgfLA/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bluebell-bistro-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 2,
#   'categories': [{'alias': 'bistros', 'title': 'Bistros'},
#    {'alias': 'mediterranean', 'title': 'Mediterranean'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 3.0,
#   'coordinates': {'latitude': 51.5581083, 'longitude': -0.1194863},
#   'transactions': [],
#   'price': '£',
#   'location': {'address1': '464 Holloway Road',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'N7 6HT',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['464 Holloway Road',
#     'London N7 6HT',
#     'United Kingdom']},
#   'phone': '+442072632241',
#   'display_phone': '+44 20 7263 2241',
#   'distance': 5163.479559916122},
#  {'id': 'iFJhJ7Zoyetax9_sL1ygaA',
#   'alias': 'bluebelles-of-portobello-london',
#   'name': 'Bluebelles of Portobello',
#   'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/sJyLxvwK8K8ECAjTv20T8w/o.jpg',
#   'is_closed': False,
#   'url': 'https://www.yelp.com/biz/bluebelles-of-portobello-london?adjust_creative=g46LAR-MG9cTZ0a9XjQ8GA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=g46LAR-MG9cTZ0a9XjQ8GA',
#   'review_count': 29,
#   'categories': [{'alias': 'cafes', 'title': 'Cafes'},
#    {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#   'rating': 4.0,
#   'coordinates': {'latitude': 51.521417, 'longitude': -0.210031},
#   'transactions': [],
#   'price': '££',
#   'location': {'address1': '320 Portobello Road',
#    'address2': '',
#    'address3': '',
#    'city': 'London',
#    'zip_code': 'W10 5RU',
#    'country': 'GB',
#    'state': 'XGL',
#    'display_address': ['320 Portobello Road',
#     'London W10 5RU',
#     'United Kingdom']},
#   'phone': '+442089684572',
#   'display_phone': '+44 20 8968 4572',
#   'distance': 5210.189669575952},
#  ...]

# %% [markdown]
# ## json to list

# %%
Business_ID = []
Bus_Name = []
Review_count = []
Rating =[]
Category_Alias = []
Category_Title = []
Lat = []
Long =[]
Price = []
Postcode = []


#for loop 
for r in london_restaurants:    
    try:
        Business_ID_1 = r['id']
    except:
        Business_ID_1 = None
    try:
        Bus_Name_1 = r['name']
    except:
        Bus_Name_1 = None
    try:
        Review_count_1 = r['review_count']
    except:
        Review_count_1 = None
    try:
        Rating_1 = r['rating']
    except:
        Rating_1 = None
    try:
        Category_Alias_1 = r['categories'][0]['alias']
    except:
        Category_Alias_1 = None
    try:
        Category_Title_1 = r['categories'][0]['title']
    except:
        Category_Title_1 = None
    try:
        Lat_1 = r['coordinates']['latitude']
    except:
        Lat_1 = None
    try:
        Long_1 = r['coordinates']['longitude']
    except:
        Long_1 = None
    try:
        Price_1 = r['price']#['price']
    except:
        Price_1 = None
    try:
        Postcode_1 = r['location']['zip_code']
    except:
        Postcode_1 = None
    #print(Category_Alias,Category_Title,Lat,Long,Postcode)
    
    Business_ID.append(Business_ID_1)
    Bus_Name.append(Bus_Name_1)
    Review_count.append(Review_count_1)
    Rating.append(Rating_1)
    Category_Alias.append(Category_Alias_1)
    Category_Title.append(Category_Title_1)
    Lat.append(Lat_1)
    Long.append(Long_1)
    Price.append(Price_1)
    Postcode.append(Postcode_1)

# %% [markdown]
# ## List to DataFrame

# %%
new_data = pd.DataFrame({ 'Business_ID':Business_ID ,
    'Bus_Name':Bus_Name ,
    'Review_count':Review_count ,
    'Rating':Rating ,
    'Category_Alias':Category_Alias ,
    'Category_Title':Category_Title ,
    'Lat':Lat ,
    'Long':Long ,
    'Price':Price ,
    'Postcode':Postcode 
})

# %%
new_data
# Out:
#                   Business_ID                         Bus_Name  Review_count  \
# 0      82I-SlGojUpp7Rzotmv9lg                           &Pasta             5
# 1      zGSyCNHv2RKiEHRgVimVJg                           &feast             1
# 2      ghg0SAC1cuKkk46ji-M9Kw     'The Black Lab' Coffee House            43
# 3      6hfGUw2-80sTXNvhijOtEQ  +65 / Plus-Six-Five Supper Club             1
# 4      08H7ypKfwASXosKQcTT6RA                 1 Blossom Street             1
# ...                       ...                              ...           ...
# 10684  CFygsi9BPaQAKLdvkaSzWA                          troybar             7
# 10685  QA1qOxc7JegRNqondeuQfA                          wimpy's             1
# 10686  6DnNZSb9Nxz3HGPVD7PJ8g                  x'ian bang bang             1
# 10687  8AiogIaCJ91r3eeurcXYSA                       Öz Erciyez             1
# 10688  XwpK0LoXAZSrkkA6U1ZmJg                  禾 Restaurant He             1
#
#        Rating Category_Alias          Category_Title        Lat      Long  \
# 0         3.5          delis                   Delis  51.512861 -0.132078
# 1         2.0        buffets                 Buffets  51.474195 -0.244208
# 2         4.0         coffee            Coffee & Tea  51.461090 -0.138673
# 3         5.0    singaporean             Singaporean  51.532459 -0.106200
# 4         3.0        italian                 Italian  51.521059 -0.077761
# ...       ...            ...                     ...        ...       ...
# 10684     3.0         venues   Venues & Event Spaces  51.527631 -0.080129
# 10685     3.0   tradamerican  American (Traditional)  51.482750 -0.107470
# 10686     5.0        chinese                 Chinese  51.516748 -0.073936
# 10687     4.0        turkish                 Turkish  51.592790 -0.069951
# 10688     5.0        chinese                 Chinese  51.519590 -0.117120
#
#       Price  Postcode
# 0        ££   W1D 6AW
# 1      None  SW13 9HH
# 2        ££   SW4 7AB
# 3      None        N1
# 4        ££    E1 6BX
# ...     ...       ...
# 10684  None    N1 6NG
# 10685  None  SE11 4BE
# 10686  None    E1 7TF
# 10687  None   N17 6QA
# 10688  None  WC1R 4PS
#
# [10689 rows x 10 columns]

# %% [markdown]
# ## export to csv

# %%
new_data.to_csv('all_yelp_listing.csv')
